# %%
import pandas as pd

# %%
# Visualisation des données
filename='data.csv'
df=pd.read_csv(filename, sep=";")
pd.set_option('display.max_columns', None)
df.head()
# Out:
# /tmp/ipykernel_3415/3291987948.py:3: DtypeWarning: Columns (17,44,74,75,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(filename, sep=";")
#        SIREN  NIC           SIRET Statut de diffusion de l'établissement  \
# 0  912239670   17  91223967000017                                      O
# 1  500250303   12  50025030300012                                      O
# 2  389091893   47  38909189300047                                      O
# 3  212505887   27  21250588700027                                      O
# 4  200053825  101  20005382500101                                      O
#
#   Date de création de l'établissement  \
# 0                          2022-04-05
# 1                          2007-09-14
# 2                          2019-01-01
# 3                          1996-12-01
# 4                          2016-01-01
#
#   Tranche de l'effectif de l'établissement  \
# 0                           3 à 5 salariés
# 1              Etablissement non employeur
# 2                         10 à 19 salariés
# 3              Etablissement non employeur
# 4              Etablissement non employeur
#
#    Tranche de l'effectif de l'établissement triable  \
# 0                                                 2
# 1                                                -1
# 2                                                11
# 3                                                -1
# 4                                                -1
#
#    Année de la tranche d'effectif de l'établissement  \
# 0                                             2023.0
# 1                                                NaN
# 2                                             2023.0
# 3                                                NaN
# 4                                                NaN
#
#   Activité principale de l'établissement  \
# 0                                 4391AZ
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Date de la dernière mise à jour de l'établissement Etablissement siège  \
# 0                          2025-02-05T03:21:54+01:00                 oui
# 1                          2025-02-04T03:24:17+01:00                 oui
# 2                          2024-03-30T07:51:21+01:00                 oui
# 3                          2024-03-30T19:49:51+01:00                 non
# 4                          2024-03-22T16:40:57+01:00                 non
#
#    Nombre de periodes de l'établissement  \
# 0                                      2
# 1                                      2
# 2                                      1
# 3                                      3
# 4                                      1
#
#   Complément d'adresse de l'établissement  Numéro de voie de l'établissement  \
# 0                                     NaN                              220.0
# 1                                     NaN                               11.0
# 2                                     NaN                               14.0
# 3                                  MAIRIE                               10.0
# 4                                  MAIRIE                                NaN
#
#   Indice de répétition de l'établissement Type de voie de l'établissement  \
# 0                                       A                             Rue
# 1                                     NaN                             Rue
# 2                                       B                             Rue
# 3                                     NaN                             Rue
# 4                                     NaN                           Place
#
#   Libellé de la voie de l'établissement Code postal de l'établissement  \
# 0                          DE FONTGRAVE                        26740.0
# 1                             CONDORCET                        94800.0
# 2                 DE LA FOSSE MONTALBOT                        91270.0
# 3                            DU PRIEURE                        25380.0
# 4                     CHARLES DE GAULLE                        50160.0
#
#   Commune de l'établissement  \
# 0     MONTBOUCHER-SUR-JABRON
# 1                  VILLEJUIF
# 2          VIGNEUX-SUR-SEINE
# 3                   VAUCLUSE
# 4         TORIGNY-LES-VILLES
#
#   Libellé de la commune de l'établissement à l'étranger  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Distribution spéciale de l'établissement Code commune de l'établissement  \
# 0                                       NaN                           26191
# 1                                       NaN                           94076
# 2                                       NaN                           91657
# 3                                       NaN                           25588
# 4                                       NaN                           50601
#
#    Code cedex de l'établissement  Libellé cedex de l'établissement  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
#
#    Code du pays de l'établissement étranger  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Libellé du pays de l'établissement étranger  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Complément d'adresse de l'établissement 2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Numero de voie de l'établissement 2  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    Indice de répétition de l'établissement 2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Type de voie de l'établissement 2  Libellé de la voie de l'établissement 2  \
# 0                                NaN                                      NaN
# 1                                NaN                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN                                      NaN
# 4                                NaN                                      NaN
#
#    Code postal de l'établissement 2  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    Libellé de la commune de l'établissement 2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Libellé de la commune de l'établissement étranger 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Distribution spéciale de l'établissement 2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Code de la commune de l'établissement 2  Code cedex de l'établissement 2  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
#
#    Libellé cedex de l'établissement 2  Code pays de l'établissement  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
#
#    Libellé du pays de l'établissement étranger.1  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Date du début de la période de l'établissement  \
# 0                                     2022-12-12
# 1                                     2023-06-05
# 2                                     2019-01-01
# 3                                     2008-01-01
# 4                                     2016-01-01
#
#   Etat administratif de l'établissement Enseigne de l'établissement 1  \
# 0                                 Actif                           NaN
# 1                                 Actif                           NaN
# 2                                 Actif                           NaN
# 3                                 Actif                   SERVICE EAU
# 4                                 Actif                   LEGS DUGAGE
#
#   Enseigne de l'établissement 2 Enseigne de l'établissement 3  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   Dénomination usuelle de l'établissement  \
# 0                                     NaN
# 1                           GILLES ZERBIB
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Activité principale de l'établissement.1  \
# 0                                   43.91A
# 1                                   47.89Z
# 2                                   43.99C
# 3                                   36.00Z
# 4                                   84.11Z
#
#   Nomenclature principale de l'établissement  \
# 0                                    NAFRev2
# 1                                    NAFRev2
# 2                                    NAFRev2
# 3                                    NAFRev2
# 4                                    NAFRev2
#
#   Caractère employeur de l'établissement  \
# 0                                    Oui
# 1                                    Non
# 2                                    Oui
# 3                                    Non
# 4                                    Non
#
#   Statut de diffusion de l'unité légale  Unité légale purgée  \
# 0                                     O                  NaN
# 1                                     O                  NaN
# 2                                     O                  NaN
# 3                                     O                  NaN
# 4                                     O                  NaN
#
#   Date de création de l'unité légale Sigle de l'unité légale  \
# 0                         2022-04-05                     NaN
# 1                         2007-09-14                     NaN
# 2                         1992-11-02                     NaN
# 3                         1978-01-01                     NaN
# 4                         2016-01-01                     NaN
#
#   Civilité de la personne physique Prénom de la personne physique 1  \
# 0                              NaN                              NaN
# 1                         Masculin                           GILLES
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   Prénom de la personne physique 2 Prénom de la personne physique 3  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   Prénom de la personne physique 4 Prénom usuel de la personne physique  \
# 0                              NaN                                  NaN
# 1                              NaN                               GILLES
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
#
#   Pseudonyme de la personne physique  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   Identifiant association de l'unité légale  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Tranche de l'effectif de l'unité légale  \
# 0                          3 à 5 salariés
# 1             Etablissement non employeur
# 2                        10 à 19 salariés
# 3                          3 à 5 salariés
# 4                        50 à 99 salariés
#
#    Tranche de l'effectif de l'unité légale triable  \
# 0                                                2
# 1                                               -1
# 2                                               11
# 3                                                2
# 4                                               21
#
#    Année de la tranche de l'effectif de l'unité légale  \
# 0                                             2023.0
# 1                                                NaN
# 2                                             2023.0
# 3                                             2023.0
# 4                                             2023.0
#
#   Date du dernier traitement de l'unité légale  \
# 0                    2024-03-22T15:26:06+01:00
# 1                    2024-03-22T15:26:06+01:00
# 2                    2024-03-22T15:26:06+01:00
# 3                    2024-03-22T15:26:06+01:00
# 4                    2024-03-28T09:46:16+01:00
#
#    Nombre de périodes de l'unité légale Catégorie de l'entreprise  \
# 0                                     2                       PME
# 1                                     3                       PME
# 2                                     4                       PME
# 3                                     5                       PME
# 4                                     2                       PME
#
#    Année de la catégorie de l'entreprise Date de début de l'unité légale  \
# 0                                   2023                      2022-12-12
# 1                                   2023                      2023-06-05
# 2                                   2023                      2019-01-01
# 3                                   2023                      2017-12-31
# 4                                   2023                      2017-12-31
#
#   Etat administratif de l'unité légale Nom de la personne physique  \
# 0                               Active                         NaN
# 1                               Active                      ZERBIB
# 2                               Active                         NaN
# 3                               Active                         NaN
# 4                               Active                         NaN
#
#   Nom d'usage de la personne physique Dénomination de l'unité légale  \
# 0                                 NaN          LES TOITURES PERENNES
# 1                                 NaN                            NaN
# 2                                 NaN                            OCB
# 3                                 NaN            COMMUNE DE VAUCLUSE
# 4                                 NaN  COMMUNE DE TORIGNY-LES-VILLES
#
#   Dénomination usuelle de l'unité légale 1  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Dénomination usuelle de l'unité légale 2  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Dénomination usuelle de l'unité légale 3  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Catégorie juridique de l'unité légale  \
# 0                                   5499
# 1                                   1000
# 2                                   5499
# 3                                   7210
# 4                                   7210
#
#   Activité principale de l'unité légale  \
# 0                                43.91A
# 1                                47.89Z
# 2                                43.99C
# 3                                84.11Z
# 4                                84.11Z
#
#   Nomenclature de l'activité principale de l'unité légale  \
# 0                                            NAFRev2
# 1                                            NAFRev2
# 2                                            NAFRev2
# 3                                            NAFRev2
# 4                                            NAFRev2
#
#    NIC du siège de l'unité légale Economie sociale et solidaire unité légale  \
# 0                              17                                          N
# 1                              12                                        NaN
# 2                              47                                          N
# 3                              19                                          N
# 4                              10                                          N
#
#   Société à mission unité légale  Caractère employeur de l'unité légale  \
# 0                            NaN                                    NaN
# 1                            NaN                                    NaN
# 2                            NaN                                    NaN
# 3                            NaN                                    NaN
# 4                            NaN                                    NaN
#
#    Code EPCI de l'établissement  \
# 0                   200040459.0
# 1                   200054781.0
# 2                   200058477.0
# 3                   200023075.0
# 4                   200066389.0
#
#                 Libellé de l'EPCI de l'établissement  \
# 0  Communauté d'agglomération Montélimar Agglomér...
# 1                           Métropole du Grand Paris
# 2  Communauté d'agglomération Val d'Yerres Val de...
# 3           Communauté de communes du Pays de Maîche
# 4          Communauté d'agglomération Saint-Lô Agglo
#
#   Code de l'arrondissement de l'établissement  \
# 0                                         262
# 1                                         943
# 2                                         912
# 3                                         252
# 4                                         504
#
#   Code du département de l'établissement Département de l'établissement  \
# 0                                     26                          Drôme
# 1                                     94                   Val-de-Marne
# 2                                     91                        Essonne
# 3                                     25                          Doubs
# 4                                     50                         Manche
#
#    Code de la région de l'établissement Région de l'établissement  \
# 0                                  84.0      Auvergne-Rhône-Alpes
# 1                                  11.0             Île-de-France
# 2                                  11.0             Île-de-France
# 3                                  27.0   Bourgogne-Franche-Comté
# 4                                  28.0                 Normandie
#
#                           Section de l'établissement  \
# 0                                       Construction
# 1  Commerce ; réparation d'automobiles et de moto...
# 2                                       Construction
# 3  Production et distribution d'eau ; assainissem...
# 4                            Administration publique
#
#                      Sous-section de l'établissement  \
# 0                Travaux de construction spécialisés
# 1  Commerce de détail, à l'exception des automobi...
# 2                Travaux de construction spécialisés
# 3          Captage, traitement et distribution d'eau
# 4  Administration publique et défense ; sécurité ...
#
#                       Division de l'établissement  \
# 0      Autres travaux de construction spécialisés
# 1    Commerce de détail sur éventaires et marchés
# 2      Autres travaux de construction spécialisés
# 3       Captage, traitement et distribution d'eau
# 4  Administration générale, économique et sociale
#
#                            Groupe de l'établissement  \
# 0                              Travaux de couverture
# 1  Autres commerces de détail sur éventaires et m...
# 2  Autres travaux de construction spécialisés n.c.a.
# 3          Captage, traitement et distribution d'eau
# 4                   Administration publique générale
#
#                            Classe de l'établissement  \
# 0                               Travaux de charpente
# 1  Autres commerces de détail sur éventaires et m...
# 2  Travaux de maçonnerie générale et gros œuvre d...
# 3          Captage, traitement et distribution d'eau
# 4                   Administration publique générale
#
#                            Section de l'unité légale  \
# 0                                       Construction
# 1  Commerce ; réparation d'automobiles et de moto...
# 2                                       Construction
# 3                            Administration publique
# 4                            Administration publique
#
#                       Sous-section de l'unité légale  \
# 0                Travaux de construction spécialisés
# 1  Commerce de détail, à l'exception des automobi...
# 2                Travaux de construction spécialisés
# 3  Administration publique et défense ; sécurité ...
# 4  Administration publique et défense ; sécurité ...
#
#                        Division de l'unité légale  \
# 0      Autres travaux de construction spécialisés
# 1    Commerce de détail sur éventaires et marchés
# 2      Autres travaux de construction spécialisés
# 3  Administration générale, économique et sociale
# 4  Administration générale, économique et sociale
#
#                             Groupe de l'unité légale  \
# 0                              Travaux de couverture
# 1  Autres commerces de détail sur éventaires et m...
# 2  Autres travaux de construction spécialisés n.c.a.
# 3                   Administration publique générale
# 4                   Administration publique générale
#
#                             Classe de l'unité légale  \
# 0                               Travaux de charpente
# 1  Autres commerces de détail sur éventaires et m...
# 2  Travaux de maçonnerie générale et gros œuvre d...
# 3                   Administration publique générale
# 4                   Administration publique générale
#
#                   Nature juridique de l'unité légale  \
# 0  Société à responsabilité limitée (sans autre i...
# 1                            Entrepreneur individuel
# 2  Société à responsabilité limitée (sans autre i...
# 3                        Commune et commune nouvelle
# 4                        Commune et commune nouvelle
#
#   Première ligne de l'adressage      Adresse de l'établissement  \
# 0                           NaN          220 A Rue DE FONTGRAVE
# 1        Monsieur GILLES ZERBIB                11 Rue CONDORCET
# 2                           NaN  14 B Rue DE LA FOSSE MONTALBOT
# 3                           NaN               10 Rue DU PRIEURE
# 4                           NaN         Place CHARLES DE GAULLE
#
#    SIRET du siège de l'unité légale  Date de fermeture de l'établissement  \
# 0                      9.122397e+13                                   NaN
# 1                      5.002503e+13                                   NaN
# 2                      3.890919e+13                                   NaN
# 3                      2.125059e+13                                   NaN
# 4                      2.000538e+13                                   NaN
#
#   Date de fermeture de l'unité légale Géolocalisation de l'établissement
# 0                                 NaN                44.547994, 4.796421
# 1                                 NaN                48.796614, 2.367839
# 2                                 NaN                48.715618, 2.434367
# 3                                 NaN                47.258419, 6.685238
# 4                                 NaN                49.035001, -0.97898

# %%
df.shape
# Out:
# (2295497, 107)

# %%
print("Basics statistics: ")
df_desc = df.describe(include="all")
display(df_desc)
print()

print("Total and percentage of missing values: ")
missing_total = df.isnull().sum().sum()
display(missing_total)
missing_percent = 100 * df.isnull().sum() / df.shape[0]
display(missing_percent[missing_percent != 0])
# Out:
# Basics statistics:
#                SIREN           NIC         SIRET  \
# count   2.295497e+06  2.295497e+06  2.295497e+06
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# mean    6.804031e+08  3.107120e+01  6.804031e+13
# std     2.278301e+08  1.978319e+02  2.278301e+13
# min     5.520176e+06  1.000000e+01  5.520176e+11
# 25%     4.804814e+08  1.400000e+01  4.804814e+13
# 50%     8.000486e+08  1.800000e+01  8.000486e+13
# 75%     8.853241e+08  2.700000e+01  8.853241e+13
# max     9.999901e+08  1.868400e+04  9.999901e+13
#
#        Statut de diffusion de l'établissement  \
# count                                 2295497
# unique                                      1
# top                                         O
# freq                                  2295497
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
#        Date de création de l'établissement  \
# count                              2295497
# unique                               19160
# top                             1900-01-01
# freq                                 12534
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# 50%                                    NaN
# 75%                                    NaN
# max                                    NaN
#
#        Tranche de l'effectif de l'établissement  \
# count                                   2295497
# unique                                       13
# top                 Etablissement non employeur
# freq                                    1868880
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
#         Tranche de l'effectif de l'établissement triable  \
# count                                       2.295497e+06
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                       -2.149081e-01
# std                                         2.485353e+00
# min                                        -1.000000e+00
# 25%                                        -1.000000e+00
# 50%                                        -1.000000e+00
# 75%                                        -1.000000e+00
# max                                         4.200000e+01
#
#         Année de la tranche d'effectif de l'établissement  \
# count                                            451131.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                               2023.0
# std                                                   0.0
# min                                                2023.0
# 25%                                                2023.0
# 50%                                                2023.0
# 75%                                                2023.0
# max                                                2023.0
#
#        Activité principale de l'établissement  \
# count                                  344707
# unique                                    521
# top                                    4399CZ
# freq                                    23318
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
#        Date de la dernière mise à jour de l'établissement Etablissement siège  \
# count                                             2295497             2295497
# unique                                             307480                   2
# top                             2024-03-22T16:40:57+01:00                 oui
# freq                                               119614             2064482
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#         Nombre de periodes de l'établissement  \
# count                            2.295497e+06
# unique                                    NaN
# top                                       NaN
# freq                                      NaN
# mean                             1.798619e+00
# std                              1.253694e+00
# min                              1.000000e+00
# 25%                              1.000000e+00
# 50%                              1.000000e+00
# 75%                              2.000000e+00
# max                              4.500000e+01
#
#        Complément d'adresse de l'établissement  \
# count                                   482986
# unique                                  299030
# top                                     MAIRIE
# freq                                     12993
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#         Numéro de voie de l'établissement  \
# count                        1.936907e+06
# unique                                NaN
# top                                   NaN
# freq                                  NaN
# mean                         9.878788e+01
# std                          3.710083e+02
# min                          0.000000e+00
# 25%                          7.000000e+00
# 50%                          2.000000e+01
# 75%                          5.900000e+01
# max                          1.131150e+05
#
#        Indice de répétition de l'établissement  \
# count                                    99214
# unique                                      35
# top                                          B
# freq                                     75363
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        Type de voie de l'établissement Libellé de la voie de l'établissement  \
# count                          2043179                               2273329
# unique                             194                                381831
# top                                Rue                      DE LA REPUBLIQUE
# freq                           1112056                                 18315
# mean                               NaN                                   NaN
# std                                NaN                                   NaN
# min                                NaN                                   NaN
# 25%                                NaN                                   NaN
# 50%                                NaN                                   NaN
# 75%                                NaN                                   NaN
# max                                NaN                                   NaN
#
#        Code postal de l'établissement Commune de l'établissement  \
# count                         2251739                    2251795
# unique                          12803                      35646
# top                             75008                      PARIS
# freq                            14960                     203277
# mean                              NaN                        NaN
# std                               NaN                        NaN
# min                               NaN                        NaN
# 25%                               NaN                        NaN
# 50%                               NaN                        NaN
# 75%                               NaN                        NaN
# max                               NaN                        NaN
#
#        Libellé de la commune de l'établissement à l'étranger  \
# count                                               41553
# unique                                              22217
# top                                              SHENZHEN
# freq                                                 2391
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Distribution spéciale de l'établissement  \
# count                                        0.0
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        Code commune de l'établissement  Code cedex de l'établissement  \
# count                          2251795                            0.0
# unique                           34260                            NaN
# top                              75108                            NaN
# freq                             27019                            NaN
# mean                               NaN                            NaN
# std                                NaN                            NaN
# min                                NaN                            NaN
# 25%                                NaN                            NaN
# 50%                                NaN                            NaN
# 75%                                NaN                            NaN
# max                                NaN                            NaN
#
#         Libellé cedex de l'établissement  \
# count                                0.0
# unique                               NaN
# top                                  NaN
# freq                                 NaN
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
#
#         Code du pays de l'établissement étranger  \
# count                               43702.000000
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                99176.406274
# std                                    74.296965
# min                                 99100.000000
# 25%                                 99131.000000
# 50%                                 99137.000000
# 75%                                 99216.000000
# max                                 99515.000000
#
#        Libellé du pays de l'établissement étranger  \
# count                                        43699
# unique                                         171
# top                                          CHINE
# freq                                         13654
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#         Complément d'adresse de l'établissement 2  \
# count                                         0.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#         Numero de voie de l'établissement 2  \
# count                                   0.0
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#         Indice de répétition de l'établissement 2  \
# count                                         0.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#         Type de voie de l'établissement 2  \
# count                                 0.0
# unique                                NaN
# top                                   NaN
# freq                                  NaN
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
#         Libellé de la voie de l'établissement 2  \
# count                                       0.0
# unique                                      NaN
# top                                         NaN
# freq                                        NaN
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
#         Code postal de l'établissement 2  \
# count                                0.0
# unique                               NaN
# top                                  NaN
# freq                                 NaN
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
#
#         Libellé de la commune de l'établissement 2  \
# count                                          0.0
# unique                                         NaN
# top                                            NaN
# freq                                           NaN
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#         Libellé de la commune de l'établissement étranger 2  \
# count                                                 0.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Distribution spéciale de l'établissement 2  \
# count                                          0.0
# unique                                         NaN
# top                                            NaN
# freq                                           NaN
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#         Code de la commune de l'établissement 2  \
# count                                       0.0
# unique                                      NaN
# top                                         NaN
# freq                                        NaN
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
#         Code cedex de l'établissement 2  Libellé cedex de l'établissement 2  \
# count                               0.0                                 0.0
# unique                              NaN                                 NaN
# top                                 NaN                                 NaN
# freq                                NaN                                 NaN
# mean                                NaN                                 NaN
# std                                 NaN                                 NaN
# min                                 NaN                                 NaN
# 25%                                 NaN                                 NaN
# 50%                                 NaN                                 NaN
# 75%                                 NaN                                 NaN
# max                                 NaN                                 NaN
#
#         Code pays de l'établissement  \
# count                            0.0
# unique                           NaN
# top                              NaN
# freq                             NaN
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
#
#         Libellé du pays de l'établissement étranger.1  \
# count                                             0.0
# unique                                            NaN
# top                                               NaN
# freq                                              NaN
# mean                                              NaN
# std                                               NaN
# min                                               NaN
# 25%                                               NaN
# 50%                                               NaN
# 75%                                               NaN
# max                                               NaN
#
#        Date du début de la période de l'établissement  \
# count                                         2295497
# unique                                           9130
# top                                        2008-01-01
# freq                                           318894
# mean                                              NaN
# std                                               NaN
# min                                               NaN
# 25%                                               NaN
# 50%                                               NaN
# 75%                                               NaN
# max                                               NaN
#
#        Etat administratif de l'établissement Enseigne de l'établissement 1  \
# count                                2295497                        241486
# unique                                     1                        181769
# top                                    Actif                        MAIRIE
# freq                                 2295497                          9027
# mean                                     NaN                           NaN
# std                                      NaN                           NaN
# min                                      NaN                           NaN
# 25%                                      NaN                           NaN
# 50%                                      NaN                           NaN
# 75%                                      NaN                           NaN
# max                                      NaN                           NaN
#
#        Enseigne de l'établissement 2 Enseigne de l'établissement 3  \
# count                           1914                           453
# unique                          1887                           452
# top                  INTERNATIONALES              CABINET JAFFE //
# freq                               4                             2
# mean                             NaN                           NaN
# std                              NaN                           NaN
# min                              NaN                           NaN
# 25%                              NaN                           NaN
# 50%                              NaN                           NaN
# 75%                              NaN                           NaN
# max                              NaN                           NaN
#
#             Dénomination usuelle de l'établissement  \
# count                                        442680
# unique                                       401878
# top     AIDE AUX FONCTIONS SUPPORTS DES ENTREPRISES
# freq                                           1182
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#        Activité principale de l'établissement.1  \
# count                                   2295497
# unique                                      725
# top                                      68.20B
# freq                                     121874
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
#        Nomenclature principale de l'établissement  \
# count                                     2295497
# unique                                          1
# top                                       NAFRev2
# freq                                      2295497
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#        Caractère employeur de l'établissement  \
# count                                 2295298
# unique                                      2
# top                                       Non
# freq                                  1777415
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
#        Statut de diffusion de l'unité légale  Unité légale purgée  \
# count                                2295497                  0.0
# unique                                     1                  NaN
# top                                        O                  NaN
# freq                                 2295497                  NaN
# mean                                     NaN                  NaN
# std                                      NaN                  NaN
# min                                      NaN                  NaN
# 25%                                      NaN                  NaN
# 50%                                      NaN                  NaN
# 75%                                      NaN                  NaN
# max                                      NaN                  NaN
#
#        Date de création de l'unité légale Sigle de l'unité légale  \
# count                             2295497                   87193
# unique                              20229                   45647
# top                            1900-01-01                    CCAS
# freq                                17667                    1252
# mean                                  NaN                     NaN
# std                                   NaN                     NaN
# min                                   NaN                     NaN
# 25%                                   NaN                     NaN
# 50%                                   NaN                     NaN
# 75%                                   NaN                     NaN
# max                                   NaN                     NaN
#
#        Civilité de la personne physique Prénom de la personne physique 1  \
# count                           1119137                          1120155
# unique                                2                            75730
# top                            Masculin                             JEAN
# freq                             669373                            15936
# mean                                NaN                              NaN
# std                                 NaN                              NaN
# min                                 NaN                              NaN
# 25%                                 NaN                              NaN
# 50%                                 NaN                              NaN
# 75%                                 NaN                              NaN
# max                                 NaN                              NaN
#
#        Prénom de la personne physique 2 Prénom de la personne physique 3  \
# count                            388726                           173111
# unique                            22120                             8562
# top                               MARIE                            MARIE
# freq                              17904                             8405
# mean                                NaN                              NaN
# std                                 NaN                              NaN
# min                                 NaN                              NaN
# 25%                                 NaN                              NaN
# 50%                                 NaN                              NaN
# 75%                                 NaN                              NaN
# max                                 NaN                              NaN
#
#        Prénom de la personne physique 4 Prénom usuel de la personne physique  \
# count                             16170                              1120155
# unique                             2236                                75730
# top                               MARIE                                 JEAN
# freq                               1440                                15936
# mean                                NaN                                  NaN
# std                                 NaN                                  NaN
# min                                 NaN                                  NaN
# 25%                                 NaN                                  NaN
# 50%                                 NaN                                  NaN
# 75%                                 NaN                                  NaN
# max                                 NaN                                  NaN
#
#        Pseudonyme de la personne physique  \
# count                               10579
# unique                               8965
# top                                 MARIE
# freq                                   20
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
#        Identifiant association de l'unité légale  \
# count                                      71270
# unique                                     59232
# top                                   W543000517
# freq                                         532
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        Tranche de l'effectif de l'unité légale  \
# count                                  2295497
# unique                                      13
# top                Etablissement non employeur
# freq                                   1761662
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#         Tranche de l'effectif de l'unité légale triable  \
# count                                      2.295497e+06
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       2.892790e-01
# std                                        3.734939e+00
# min                                       -1.000000e+00
# 25%                                       -1.000000e+00
# 50%                                       -1.000000e+00
# 75%                                       -1.000000e+00
# max                                        4.200000e+01
#
#         Année de la tranche de l'effectif de l'unité légale  \
# count                                            561635.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                               2023.0
# std                                                   0.0
# min                                                2023.0
# 25%                                                2023.0
# 50%                                                2023.0
# 75%                                                2023.0
# max                                                2023.0
#
#        Date du dernier traitement de l'unité légale  \
# count                                       2295497
# unique                                       327118
# top                       2024-03-22T15:26:06+01:00
# freq                                        1864985
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#         Nombre de périodes de l'unité légale Catégorie de l'entreprise  \
# count                           2.295497e+06                   2295497
# unique                                   NaN                         1
# top                                      NaN                       PME
# freq                                     NaN                   2295497
# mean                            2.734171e+00                       NaN
# std                             1.958802e+00                       NaN
# min                             1.000000e+00                       NaN
# 25%                             1.000000e+00                       NaN
# 50%                             2.000000e+00                       NaN
# 75%                             4.000000e+00                       NaN
# max                             4.700000e+01                       NaN
#
#         Année de la catégorie de l'entreprise Date de début de l'unité légale  \
# count                               2295497.0                         2295497
# unique                                    NaN                            8759
# top                                       NaN                      2008-01-01
# freq                                      NaN                          299222
# mean                                   2023.0                             NaN
# std                                       0.0                             NaN
# min                                    2023.0                             NaN
# 25%                                    2023.0                             NaN
# 50%                                    2023.0                             NaN
# 75%                                    2023.0                             NaN
# max                                    2023.0                             NaN
#
#        Etat administratif de l'unité légale Nom de la personne physique  \
# count                               2295497                     1120164
# unique                                    2                      297872
# top                                  Active                      MARTIN
# freq                                2295491                        2947
# mean                                    NaN                         NaN
# std                                     NaN                         NaN
# min                                     NaN                         NaN
# 25%                                     NaN                         NaN
# 50%                                     NaN                         NaN
# 75%                                     NaN                         NaN
# max                                     NaN                         NaN
#
#        Nom d'usage de la personne physique    Dénomination de l'unité légale  \
# count                               160272                           1175329
# unique                               84210                            934442
# top                                 MARTIN  CENTRE COMMUNAL D'ACTION SOCIALE
# freq                                   427                               970
# mean                                   NaN                               NaN
# std                                    NaN                               NaN
# min                                    NaN                               NaN
# 25%                                    NaN                               NaN
# 50%                                    NaN                               NaN
# 75%                                    NaN                               NaN
# max                                    NaN                               NaN
#
#        Dénomination usuelle de l'unité légale 1  \
# count                                    118102
# unique                                    90725
# top                                 INTERMARCHE
# freq                                        248
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
#        Dénomination usuelle de l'unité légale 2  \
# count                                       676
# unique                                      493
# top                            AGENCE FAROUAULT
# freq                                          9
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
#        Dénomination usuelle de l'unité légale 3  \
# count                                       204
# unique                                      142
# top                                     SHIMMER
# freq                                          8
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
#         Catégorie juridique de l'unité légale  \
# count                            2.295497e+06
# unique                                    NaN
# top                                       NaN
# freq                                      NaN
# mean                             3.529491e+03
# std                              2.645976e+03
# min                              1.000000e+03
# 25%                              1.000000e+03
# 50%                              3.220000e+03
# 75%                              5.710000e+03
# max                              9.970000e+03
#
#        Activité principale de l'unité légale  \
# count                                2295497
# unique                                   710
# top                                   68.20B
# freq                                  122241
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#        Nomenclature de l'activité principale de l'unité légale  \
# count                                             2295497
# unique                                                  1
# top                                               NAFRev2
# freq                                              2295497
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         NIC du siège de l'unité légale  \
# count                     2.295497e+06
# unique                             NaN
# top                                NaN
# freq                               NaN
# mean                      2.411091e+01
# std                       5.276748e+01
# min                       1.000000e+01
# 25%                       1.400000e+01
# 50%                       1.800000e+01
# 75%                       2.600000e+01
# max                       1.868400e+04
#
#        Economie sociale et solidaire unité légale  \
# count                                      792738
# unique                                          2
# top                                             N
# freq                                       701323
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#        Société à mission unité légale  Caractère employeur de l'unité légale  \
# count                           10441                                    0.0
# unique                              2                                    NaN
# top                                 N                                    NaN
# freq                            10422                                    NaN
# mean                              NaN                                    NaN
# std                               NaN                                    NaN
# min                               NaN                                    NaN
# 25%                               NaN                                    NaN
# 50%                               NaN                                    NaN
# 75%                               NaN                                    NaN
# max                               NaN                                    NaN
#
#         Code EPCI de l'établissement Libellé de l'EPCI de l'établissement  \
# count                   2.245026e+06                              2245025
# unique                           NaN                                 1253
# top                              NaN             Métropole du Grand Paris
# freq                             NaN                               379516
# mean                    2.149121e+08                                  NaN
# std                     2.123608e+07                                  NaN
# min                     2.000002e+08                                  NaN
# 25%                     2.000548e+08                                  NaN
# 50%                     2.000678e+08                                  NaN
# 75%                     2.431008e+08                                  NaN
# max                     2.497401e+08                                  NaN
#
#        Code de l'arrondissement de l'établissement  \
# count                                      2245341
# unique                                         334
# top                                            751
# freq                                        205267
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        Code du département de l'établissement Département de l'établissement  \
# count                                 2249799                        2249799
# unique                                    106                            106
# top                                        75                          Paris
# freq                                   205267                         205267
# mean                                      NaN                            NaN
# std                                       NaN                            NaN
# min                                       NaN                            NaN
# 25%                                       NaN                            NaN
# 50%                                       NaN                            NaN
# 75%                                       NaN                            NaN
# max                                       NaN                            NaN
#
#         Code de la région de l'établissement Région de l'établissement  \
# count                           2.249799e+06                   2249799
# unique                                   NaN                        23
# top                                      NaN             Île-de-France
# freq                                     NaN                    530871
# mean                            5.080247e+01                       NaN
# std                             5.173661e+01                       NaN
# min                             1.000000e+00                       NaN
# 25%                             1.100000e+01                       NaN
# 50%                             5.200000e+01                       NaN
# 75%                             7.600000e+01                       NaN
# max                             9.860000e+02                       NaN
#
#                                Section de l'établissement  \
# count                                             2295496
# unique                                                 22
# top     Commerce ; réparation d'automobiles et de moto...
# freq                                               364540
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                           Sous-section de l'établissement  \
# count                                             2295496
# unique                                                 88
# top     Commerce de détail, à l'exception des automobi...
# freq                                               242279
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                               Division de l'établissement  \
# count                                             2295496
# unique                                                270
# top     Location et exploitation de biens immobiliers ...
# freq                                               182046
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                 Groupe de l'établissement  \
# count                                             2295496
# unique                                                610
# top     Location et exploitation de biens immobiliers ...
# freq                                               182046
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                 Classe de l'établissement  \
# count                                             2295496
# unique                                                725
# top     Location de terrains et d'autres biens immobil...
# freq                                               121874
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                 Section de l'unité légale  \
# count                                             2295496
# unique                                                 22
# top     Commerce ; réparation d'automobiles et de moto...
# freq                                               371847
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                            Sous-section de l'unité légale  \
# count                                             2295496
# unique                                                 88
# top     Commerce de détail, à l'exception des automobi...
# freq                                               245453
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                Division de l'unité légale  \
# count                                             2295496
# unique                                                265
# top     Location et exploitation de biens immobiliers ...
# freq                                               162556
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  Groupe de l'unité légale  \
# count                                             2295496
# unique                                                595
# top     Location et exploitation de biens immobiliers ...
# freq                                               162556
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  Classe de l'unité légale  \
# count                                             2295496
# unique                                                710
# top     Location de terrains et d'autres biens immobil...
# freq                                               122241
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Nature juridique de l'unité légale Première ligne de l'adressage  \
# count                             2295496                       1119137
# unique                                219                        968684
# top               Entrepreneur individuel       Monsieur MAMADOU DIALLO
# freq                              1120166                            91
# mean                                  NaN                           NaN
# std                                   NaN                           NaN
# min                                   NaN                           NaN
# 25%                                   NaN                           NaN
# 50%                                   NaN                           NaN
# 75%                                   NaN                           NaN
# max                                   NaN                           NaN
#
#        Adresse de l'établissement  SIRET du siège de l'unité légale  \
# count                     2273407                      2.295496e+06
# unique                    1258397                               NaN
# top                      LE BOURG                               NaN
# freq                         4570                               NaN
# mean                          NaN                      6.804033e+13
# std                           NaN                      2.278300e+13
# min                           NaN                      5.520176e+11
# 25%                           NaN                      4.804816e+13
# 50%                           NaN                      8.000486e+13
# 75%                           NaN                      8.853241e+13
# max                           NaN                      9.999901e+13
#
#         Date de fermeture de l'établissement  \
# count                                    0.0
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#        Date de fermeture de l'unité légale Géolocalisation de l'établissement
# count                                    4                            2262117
# unique                                   4                            1511389
# top                             2025-05-20              14.596147, -61.045619
# freq                                     1                               2291
# mean                                   NaN                                NaN
# std                                    NaN                                NaN
# min                                    NaN                                NaN
# 25%                                    NaN                                NaN
# 50%                                    NaN                                NaN
# 75%                                    NaN                                NaN
# max                                    NaN                                NaN
# Total and percentage of missing values:
# np.int64(106865434)
# Année de la tranche d'effectif de l'établissement     80.347132
# Activité principale de l'établissement                84.983339
# Complément d'adresse de l'établissement               78.959415
# Numéro de voie de l'établissement                     15.621454
# Indice de répétition de l'établissement               95.677886
#                                                         ...
# Adresse de l'établissement                             0.962319
# SIRET du siège de l'unité légale                       0.000044
# Date de fermeture de l'établissement                 100.000000
# Date de fermeture de l'unité légale                   99.999826
# Géolocalisation de l'établissement                     1.454151
# Length: 79, dtype: float64

# %% [markdown]
# ---
